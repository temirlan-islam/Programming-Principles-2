# %%
mylist = ['apple', 'banana', 'cherry']
mylist[0] = 'kiwi'
print(mylist[1])
# Out:
# banana

# %%
fruits = ["apple", "banana", "cherry"]
fruits[0] = "kiwi"
print(fruits)
# Out:
# ['kiwi', 'banana', 'cherry']

# %%
mylist = ['apple', 'banana', 'cherry']
mylist[1:2] = ['kiwi', 'mango']
print(mylist[2])
# Out:
# mango
