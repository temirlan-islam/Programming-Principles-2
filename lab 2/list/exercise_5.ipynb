# %%
fruits = ["apple", "banana", "cherry"]
fruits.remove("banana")

# %%
mylist = ['apple', 'banana', 'cherry']
mylist.pop(1)
print(mylist)
# Out:
# ['apple', 'cherry']

# %%
fruits = ['apple', 'banana', 'cherry']
fruits.clear()
