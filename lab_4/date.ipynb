# %%
from datetime import date,  timedelta, datetime
current = date.today() - timedelta(5)
print("Current time: ", date.today())
print("Substact five days : ",current)
# Out:
# Current time:  2025-02-20
# Substact five days :  2025-02-15

# %%
from datetime import date,  timedelta, datetime
current = date.today() - timedelta(1)
current1 = date.today() +timedelta(1)
print("yesterday:" , current)
print("today:" , date.today())
print("tomorrow:" , current1)
# Out:
# yesterday: 2025-02-19
# today: 2025-02-20
# tomorrow: 2025-02-21

# %%
from datetime import datetime
current_time=datetime.now().replace(microsecond=0)
print(current_time)
# Out:
# 2025-02-20 21:24:23

# %%
from datetime import date,timedelta,datetime
keshe = datetime.now() - timedelta(1)
bugin = datetime.now()

keshe = datetime.timestamp(keshe)
bugin = datetime.timestamp(bugin)

print( bugin - keshe )
# Out:
# 86400.0
